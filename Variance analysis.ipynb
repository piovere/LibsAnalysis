# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA

# %%
df = "data/data.csv"

# %%
data = np.loadtxt(df, delimiter=",")

# %%
data.shape
# Out:
# (11738, 220)

# %%
data = data.reshape(11738, 20, 11)
np.var(data, axis=1).shape
# Out:
# (11738, 11)

# %%
plt.plot(np.var(data, axis=1)[:,0] / np.mean(data, axis=1)[:,0])
plt.show()
# Out:
# /Users/jrpowers-luhn/anaconda/envs/libs/lib/python3.5/site-packages/ipykernel/__main__.py:1: RuntimeWarning: invalid value encountered in true_divide
#   if __name__ == '__main__':

# %%
data.shape
# Out:
# (11738, 20, 11)

# %%
avg = data[:11730].reshape(1173, 10, 20, 11)

# %%
avg.shape
# Out:
# (1173, 10, 20, 11)

# %%
avg = np.mean(avg, axis=1)

# %%
avg.shape
# Out:
# (1173, 20, 11)

# %%
plt.figure(figsize=(20,10))
plt.plot(np.var(avg, axis=1)[:,0])
plt.show()

# %%
np.sum(data, axis=1)
# Out:
# array([[  2.78200000e+03,   2.78900000e+03,   2.77800000e+03, ...,
#           2.78400000e+03,   2.78400000e+03,   2.79100000e+03],
#        [  2.76700000e+03,   2.76600000e+03,   2.76900000e+03, ...,
#           2.76800000e+03,   2.76800000e+03,   2.76600000e+03],
#        [  2.76500000e+03,   2.77100000e+03,   2.77400000e+03, ...,
#           2.78300000e+03,   2.76600000e+03,   2.76800000e+03],
#        ...,
#        [  1.54000000e-02,   1.54000000e-02,   7.70000000e-03, ...,
#           1.54000000e-02,   1.54000000e-02,   1.54000000e-02],
#        [  1.33800000e-01,   1.33800000e-01,   1.78400000e-01, ...,
#           1.33800000e-01,   1.33800000e-01,   1.78400000e-01],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00]])

# %%
PCA(data[:,:,0])
# Out:
# PCA(copy=True, iterated_power='auto',
#   n_components=array([[  1.40000e+02,   1.41000e+02, ...,   1.38000e+02,   1.39000e+02],
#        [  1.40000e+02,   1.40000e+02, ...,   1.37000e+02,   1.36000e+02],
#        ...,
#        [  0.00000e+00,   0.00000e+00, ...,   0.00000e+00,   4.46000e-02],
#        [  0.00000e+00,   0.00000e+00, ...,   0.00000e+00,   0.00000e+00]]),
#   random_state=None, svd_solver='auto', tol=0.0, whiten=False)

# %%
plt.figure(figsize=(20,10))
plt.plot(data[:,0,0])
plt.xlim(7100,7200)
#plt.ylim(0,250)
plt.show()
